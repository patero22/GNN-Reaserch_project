# %% [markdown]
# <a href="https://colab.research.google.com/github/patero22/GNN-Reaserch_project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Message passing na COO i CSR

# %%
pip install torch torchvision torchaudio torch-geometric dgl memory-profiler
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 31.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio torch-geometric dgl torchdata
# Out:
# Found existing installation: torch 2.3.0+cu121
# Uninstalling torch-2.3.0+cu121:
#   Successfully uninstalled torch-2.3.0+cu121
# Found existing installation: torchvision 0.18.0+cu121
# Uninstalling torchvision-0.18.0+cu121:
#   Successfully uninstalled torchvision-0.18.0+cu121
# Found existing installation: torchaudio 2.3.0+cu121
# Uninstalling torchaudio-2.3.0+cu121:
#   Successfully uninstalled torchaudio-2.3.0+cu121
# Found existing installation: torch_geometric 2.5.3
# Uninstalling torch_geometric-2.5.3:
#   Successfully uninstalled torch_geometric-2.5.3
# Found existing installation: dgl 2.1.0
# Uninstalling dgl-2.1.0:
#   Successfully uninstalled dgl-2.1.0
# Found existing installation: torchdata 0.7.1
# Uninstalling torchdata-0.7.1:
#   Successfully uninstalled torchdata-0.7.1

# %%
# !pip install torch==2.2.2 torchvision==0.17.1 torchaudio==2.2.2
# !pip install torch-geometric==1.7.2
# !pip install dgl==1.1.2
# !pip install memory-profiler
# Out:
# ...
#   Using cached torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
# ...
#   Using cached torchvision-0.17.1-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 2.7 MB/s eta 0:00:00
# ...
# INFO: pip is looking at multiple versions of torchvision to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install torch==2.2.2 and torchvision==0.17.1 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested torch==2.2.2
#     torchvision 0.17.1 depends on torch==2.2.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ...

# %% [markdown]
# ### Define Models and Profiling Function
# Define Models and Profiling Function

# %% [markdown]
# ### Define the Models and Message Passing Mechanisms
# We'll define GCN, GAT, GraphSAGE, and PNA models using both PyTorch Geometric and DGL.

# %%
import dgl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-fd726d2cda90> in <cell line: 1>()
# ----> 1 import dgl
#
# /usr/local/lib/python3.10/dist-packages/dgl/__init__.py in <module>
#      14 from .backend import backend_name, load_backend  # usort: skip
#      15
# ---> 16 from . import (
#      17     container,
#      18     cuda,
#
# /usr/local/lib/python3.10/dist-packages/dgl/dataloading/__init__.py in <module>
#      11 if F.get_preferred_backend() == "pytorch":
#      12     from .spot_target import *
# ---> 13     from .dataloader import *
#      14     from .dist_dataloader import *
#
# /usr/local/lib/python3.10/dist-packages/dgl/dataloading/dataloader.py in <module>
#      25 from ..batch import batch as batch_graphs
#      26 from ..cuda import GPUCache
# ---> 27 from ..distributed import DistGraph
#      28 from ..frame import LazyFeature
# ...

# %%
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch_geometric.datasets import KarateClub, Planetoid
from torch_geometric.nn import GCNConv, GATConv, SAGEConv, PNAConv
from memory_profiler import memory_usage
import time

from dgl.data import KarateClubDataset, CiteseerGraphDataset
from dgl.nn.pytorch import GraphConv, GATConv, SAGEConv

# Define PyG Models
class GCN(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, 16)
        self.conv2 = GCNConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

class GAT(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, 8, heads=8)
        self.conv2 = GATConv(8*8, out_channels, heads=1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.elu(x)
        x = self.conv2(x, edge_index)
        return x

class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GraphSAGE, self).__init__()
        self.conv1 = SAGEConv(in_channels, 16)
        self.conv2 = SAGEConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

class PNA(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PNA, self).__init__()
        aggregators = ['mean', 'min', 'max', 'std']
        scalers = ['identity', 'amplification', 'attenuation']
        self.conv1 = PNAConv(in_channels, 16, aggregators, scalers)
        self.conv2 = PNAConv(16, out_channels, aggregators, scalers)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

# Define DGL Models
class GCN_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GCN_DGL, self).__init__()
        self.conv1 = GraphConv(in_feats, 16)
        self.conv2 = GraphConv(16, out_feats)

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.relu(x)
        x = self.conv2(g, x)
        return x

class GAT_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GAT_DGL, self).__init__()
        self.conv1 = GATConv(in_feats, 8, num_heads=8)
        self.conv2 = GATConv(8*8, out_feats, num_heads=1)

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.elu(x)
        x = self.conv2(g, x)
        return x

class GraphSAGE_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GraphSAGE_DGL, self).__init__()
        self.conv1 = SAGEConv(in_feats, 16, 'mean')
        self.conv2 = SAGEConv(16, out_feats, 'mean')

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.relu(x)
        x = self.conv2(g, x)
        return x

# Profiling function
def profile_model(model, data, device, dgl=False):
    data = data.to(device)
    model = model.to(device)

    def forward_pass():
        if dgl:
            model(data, data.ndata['feat'])
        else:
            model(data)

    # Measure time
    start_time = time.time()
    for _ in range(100):
        forward_pass()
    end_time = time.time()

    # Measure peak memory usage
    mem_usage = memory_usage(forward_pass, interval=0.1)

    return (end_time - start_time) / 100, max(mem_usage)

# Define devices
device_cpu = torch.device('cpu')
device_gpu = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-78e802f55690> in <cell line: 8>()
#       6 from memory_profiler import memory_usage
#       7 import time
# ----> 8 import dgl
#       9 from dgl.data import KarateClubDataset, CiteseerGraphDataset
#      10 from dgl.nn.pytorch import GraphConv, GATConv, SAGEConv
#
# /usr/local/lib/python3.10/dist-packages/dgl/__init__.py in <module>
#      14 from .backend import backend_name, load_backend  # usort: skip
#      15
# ---> 16 from . import (
#      17     container,
#      18     cuda,
#
# /usr/local/lib/python3.10/dist-packages/dgl/dataloading/__init__.py in <module>
#      11 if F.get_preferred_backend() == "pytorch":
#      12     from .spot_target import *
# ---> 13     from .dataloader import *
#      14     from .dist_dataloader import *
#
# ...

# %% [markdown]
# ### Load Datasets and Perform Tests
# PyTorch Geometric Implementation

# %%
# Load Karate Club dataset for PyG
dataset_karate = KarateClub()
data_karate = dataset_karate[0]

# Load Citeseer dataset for PyG
dataset_citeseer = Planetoid(root='data/Citeseer', name='Citeseer')
data_citeseer = dataset_citeseer[0]

# Test GCN on CPU and GPU for PyG Karate Club
gcn_model_pyg = GCN(dataset_karate.num_features, dataset_karate.num_classes)
time_cpu, mem_cpu = profile_model(gcn_model_pyg, data_karate, device_cpu)
time_gpu, mem_gpu = profile_model(gcn_model_pyg, data_karate, device_gpu)
print(f'PyG Karate Club GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'PyG Karate Club GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# Test GCN on CPU and GPU for PyG Citeseer
gcn_model_pyg = GCN(dataset_citeseer.num_features, dataset_citeseer.num_classes)
time_cpu, mem_cpu = profile_model(gcn_model_pyg, data_citeseer, device_cpu)
time_gpu, mem_gpu = profile_model(gcn_model_pyg, data_citeseer, device_gpu)
print(f'PyG Citeseer GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'PyG Citeseer GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# %% [markdown]
# #### DGL Implementation

# %%
# Load Karate Club dataset for DGL
def load_karate_dgl():
    dataset = KarateClubDataset()
    graph = dataset[0]
    return graph

# Load Citeseer dataset for DGL
def load_citeseer_dgl():
    dataset = CiteseerGraphDataset()
    graph = dataset[0]
    return graph

graph_karate_dgl = load_karate_dgl()
graph_citeseer_dgl = load_citeseer_dgl()

# Test GCN on CPU and GPU for DGL Karate Club
gcn_model_dgl = GCN_DGL(graph_karate_dgl.ndata['feat'].shape[1], graph_karate_dgl.ndata['label'].max().item() + 1)
time_cpu, mem_cpu = profile_model(gcn_model_dgl, graph_karate_dgl, device_cpu, dgl=True)
time_gpu, mem_gpu = profile_model(gcn_model_dgl, graph_karate_dgl, device_gpu, dgl=True)
print(f'DGL Karate Club GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'DGL Karate Club GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# Test GCN on CPU and GPU for DGL Citeseer
gcn_model_dgl = GCN_DGL(graph_citeseer_dgl.ndata['feat'].shape[1], graph_citeseer_dgl.ndata['label'].max().item() + 1)
time_cpu, mem_cpu = profile_model(gcn_model_dgl, graph_citeseer_dgl, device_cpu, dgl=True)
time_gpu, mem_gpu = profile_model(gcn_model_dgl, graph_citeseer_dgl, device_gpu, dgl=True)
print(f'DGL Citeseer GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'DGL Citeseer GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# %% [markdown]
# #### PyTorch Geometric Models

# %%
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch_geometric.datasets import Reddit
from torch_geometric.nn import GCNConv, GATConv, SAGEConv, PNAConv
from memory_profiler import memory_usage
import time

# Load Reddit dataset for PyG
dataset_pyg = Reddit(root='data/Reddit')
data_pyg = dataset_pyg[0]

# Define PyG Models
class GCN(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, 16)
        self.conv2 = GCNConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

class GAT(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, 8, heads=8)
        self.conv2 = GATConv(8*8, out_channels, heads=1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.elu(x)
        x = self.conv2(x, edge_index)
        return x

class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GraphSAGE, self).__init__()
        self.conv1 = SAGEConv(in_channels, 16)
        self.conv2 = SAGEConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

class PNA(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PNA, self).__init__()
        aggregators = ['mean', 'min', 'max', 'std']
        scalers = ['identity', 'amplification', 'attenuation']
        self.conv1 = PNAConv(in_channels, 16, aggregators, scalers)
        self.conv2 = PNAConv(16, out_channels, aggregators, scalers)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

# Profiling function
def profile_model(model, data, device):
    data = data.to(device)
    model = model.to(device)

    def forward_pass():
        model(data)

    # Measure time
    start_time = time.time()
    for _ in range(100):
        forward_pass()
    end_time = time.time()

    # Measure peak memory usage
    mem_usage = memory_usage(forward_pass, interval=0.1)

    return (end_time - start_time) / 100, max(mem_usage)

# Define devices
device_cpu = torch.device('cpu')
device_gpu = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Test GCN on CPU and GPU
gcn_model_pyg = GCN(dataset_pyg.num_features, dataset_pyg.num_classes)
time_cpu, mem_cpu = profile_model(gcn_model_pyg, data_pyg, device_cpu)
time_gpu, mem_gpu = profile_model(gcn_model_pyg, data_pyg, device_gpu)
print(f'PyG GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'PyG GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# %% [markdown]
# ## Handle DGL Dataset and Define Models

# %% [markdown]
# #### DGL Models

# %%
import dgl
from dgl.nn.pytorch import GraphConv, GATConv, SAGEConv

# Load Reddit dataset for DGL
def load_reddit_dgl():
    dataset = dgl.data.RedditDataset()
    graph = dataset[0]
    return graph

graph_dgl = load_reddit_dgl()

# Define DGL Models
class GCN_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GCN_DGL, self).__init__()
        self.conv1 = GraphConv(in_feats, 16)
        self.conv2 = GraphConv(16, out_feats)

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.relu(x)
        x = self.conv2(g, x)
        return x

class GAT_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GAT_DGL, self).__init__()
        self.conv1 = GATConv(in_feats, 8, num_heads=8)
        self.conv2 = GATConv(8*8, out_feats, num_heads=1)

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.elu(x)
        x = self.conv2(g, x)
        return x

class GraphSAGE_DGL(torch.nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GraphSAGE_DGL, self).__init__()
        self.conv1 = SAGEConv(in_feats, 16, 'mean')
        self.conv2 = SAGEConv(16, out_feats, 'mean')

    def forward(self, g, features):
        x = self.conv1(g, features)
        x = F.relu(x)
        x = self.conv2(g, x)
        return x

# Test GCN on CPU and GPU for DGL
gcn_model_dgl = GCN_DGL(graph_dgl.ndata['feat'].shape[1], graph_dgl.ndata['label'].max().item() + 1)
time_cpu, mem_cpu = profile_model(gcn_model_dgl, graph_dgl, device_cpu)
time_gpu, mem_gpu = profile_model(gcn_model_dgl, graph_dgl, device_gpu)
print(f'DGL GCN on CPU: {time_cpu:.6f} seconds per iteration, {mem_cpu:.2f} MB peak memory')
print(f'DGL GCN on GPU: {time_gpu:.6f} seconds per iteration, {mem_gpu:.2f} MB peak memory')

# %% [markdown]
# **bold text![Zrzut ekranu 2024-07-16 194831.png](data:image/png;base64,...)**
